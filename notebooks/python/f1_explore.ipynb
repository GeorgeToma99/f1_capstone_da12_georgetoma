# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
f1_19_race_results =  pd.read_csv('../../data/formula1_datasets/formula1_2019season_raceresults.csv')

# %%
f1_19_drivers =  pd.read_csv('../../data/formula1_datasets/formula1_2019season_drivers.csv')

# %%
f1_20_race_results =  pd.read_csv('../../data/formula1_datasets/formula1_2020season_raceresults.csv')

# %%
f1_20_drivers =  pd.read_csv('../../data/formula1_datasets/formula1_2020season_drivers.csv')

# %%
f1_21_race_results =  pd.read_csv('../../data/formula1_datasets/formula1_2021season_raceresults.csv')

# %%
f1_21_drivers =  pd.read_csv('../../data/formula1_datasets/formula1_2021season_drivers.csv')

# %%
f1_22_race_results =  pd.read_csv('../../data/formula1_datasets/formula1_2022season_raceresults.csv')

# %%
f1_22_drivers =  pd.read_csv('../../data/formula1_datasets/formula1_2022season_drivers.csv')

# %%
f1_23_race_results =  pd.read_csv('../../data/formula1_datasets/formula1_2023season_raceresults.csv')

# %%
f1_23_drivers =  pd.read_csv('../../data/formula1_datasets/formula1_2023season_drivers.csv')

# %%
f1_24_race_results =  pd.read_csv('../../data/formula1_datasets/formula1_2024season_raceresults.csv')

# %%
f1_constructors =  pd.read_csv('../../data/archive/constructors.csv')

# %%
f1_qualy =  pd.read_csv('../../data/archive/qualifying.csv')

# %%
f1_constructor_results =  pd.read_csv('../../data/archive/constructor_results.csv')

# %%
f1_constructor_standings =  pd.read_csv('../../data/archive/constructor_standings.csv')

# %%
f1_standings =  pd.read_csv('../../data/archive/driver_standings.csv')

# %%
f1_lap_times =  pd.read_csv('../../data/archive/lap_times.csv')

# %%
f1_status =  pd.read_csv('../../data/archive/status.csv')

# %%
f1_sprint_results =  pd.read_csv('../../data/archive/sprint_results.csv')

# %%
f1_drivers =  pd.read_csv('../../data/archive/drivers.csv')

# %%
f1_races =  pd.read_csv('../../data/archive/races.csv')

# %%
f1_lap_times.head()
# Out:
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
# 2     841        20    3         1  1:32.713         92713
# 3     841        20    4         1  1:32.803         92803
# 4     841        20    5         1  1:32.342         92342

# %%
f1_standings.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
f1_drivers.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
f1_races.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# ...

# %%
f1_qualy.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          1      18         1              1      22         1  1:26.572
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
# Used to filter for Max and other drivers

f1_drivers_ver = f1_drivers[f1_drivers['surname'] == 'Verstappen']
f1_drivers_ver
# Out:
#      driverId       driverRef number code forename     surname         dob  \
# 49         50      verstappen     \N   \N      Jos  Verstappen  1972-03-04
# 829       830  max_verstappen     33  VER      Max  Verstappen  1997-09-30
#
#     nationality                                          url
# 49        Dutch  http://en.wikipedia.org/wiki/Jos_Verstappen
# 829       Dutch  http://en.wikipedia.org/wiki/Max_Verstappen

# %%
f1_drivers_selects = f1_drivers[f1_drivers['driverId'].isin([815,848,830])]

# %%
f1_drivers_selects
# Out:
#      driverId       driverRef number code   forename     surname         dob  \
# 814       815           perez     11  PER     Sergio       Pérez  1990-01-26
# 829       830  max_verstappen     33  VER        Max  Verstappen  1997-09-30
# 846       848           albon     23  ALB  Alexander       Albon  1996-03-23
#
#     nationality                                             url
# 814     Mexican  http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez
# 829       Dutch     http://en.wikipedia.org/wiki/Max_Verstappen
# 846        Thai    http://en.wikipedia.org/wiki/Alexander_Albon

# %%
f1_19_drivers.head()
# Out:
#              Driver  Number             Team         Country  Podiums  Points  \
# 0    Lewis Hamilton      44         Mercedes  United Kingdom      151    3431
# 1   Valtteri Bottas      77         Mercedes         Finland       45    1289
# 2    Max Verstappen      33  Red Bull Racing     Netherlands       31     948
# 3   Charles Leclerc      16          Ferrari          Monaco       10     303
# 4  Sebastian Vettel       5          Ferrari         Germany      120    2985
#
#    Grands Prix Entered  World Championships Highest Race Finish  \
# 0                  250                    6              1(x84)
# 1                  140                    0               1(x7)
# 2                  102                    0               1(x8)
# 3                   42                    0               1(x2)
# 4                  241                    4              1(x53)
#
#    Highest Grid Position Date of Birth       Place of Birth
# ...

# %%
f1_23_race_results['Driver'].unique()
# Out:
# array(['Max Verstappen', 'Sergio Perez', 'Fernando Alonso',
#        'Carlos Sainz', 'Lewis Hamilton', 'Lance Stroll', 'George Russell',
#        'Valtteri Bottas', 'Pierre Gasly', 'Alexander Albon',
#        'Yuki Tsunoda', 'Logan Sargeant', 'Kevin Magnussen',
#        'Nyck De Vries', 'Nico Hulkenberg', 'Guanyu Zhou', 'Lando Norris',
#        'Esteban Ocon', 'Charles Leclerc', 'Oscar Piastri',
#        'Daniel Ricciardo', 'Liam Lawson'], dtype=object)

# %%
f1_19_race_results_selects = f1_19_race_results[f1_19_race_results['Driver'].isin(['Max Verstappen', 'Alexander Albon', 'Sergio Perez', 'Pierre Gasly'])]

# %%
f1_19_race_results_selects.head()
# Out:
#         Track Position  No           Driver                       Team  \
# 2   Australia        3  33   Max Verstappen      Red Bull Racing Honda
# 10  Australia       11  10     Pierre Gasly      Red Bull Racing Honda
# 12  Australia       13  11     Sergio Perez  Racing Point BWT Mercedes
# 13  Australia       14  23  Alexander Albon  Scuderia Toro Rosso Honda
# 23    Bahrain        4  33   Max Verstappen      Red Bull Racing Honda
#
#     Starting Grid  Laps Total Time/Gap/Retirement  Points Fastest Lap
# 2               4    58                   +22.520      15          No
# 10             17    57                    +1 lap       0          No
# 12             10    57                    +1 lap       0          No
# 13             13    57                    +1 lap       0          No
# 23              5    57                    +6.408      12          No

# %%
f1_20_race_results_selects = f1_20_race_results[f1_20_race_results['Driver'].isin(['Max Verstappen', 'Alexander Albon', 'Sergio Perez'])]

# %%
f1_20_race_results_selects.head()
# Out:
#       Track Position  No           Driver                       Team  \
# 5   Austria        6  11     Sergio Perez  Racing Point BWT Mercedes
# 12  Austria       13  23  Alexander Albon      Red Bull Racing Honda
# 19  Austria       NC  33   Max Verstappen      Red Bull Racing Honda
# 22   Styria        3  33   Max Verstappen      Red Bull Racing Honda
# 23   Styria        4  23  Alexander Albon      Red Bull Racing Honda
#
#     Starting Grid  Laps Total Time/Gap/Retirement  Points Fastest Lap
# 5               6    71                   +15.092       8          No
# 12              4    67                       DNF       0          No
# 19              2    11                       DNF       0          No
# 22              2    71                   +33.698      15          No
# 23              6    71                   +44.400      12          No

# %%
f1_21_race_results_selects = f1_21_race_results[f1_21_race_results['Driver'].isin(['Max Verstappen', 'Alexander Albon', 'Sergio Perez'])]

# %%
f1_21_race_results_selects.head()
# Out:
#              Track Position  No          Driver                   Team  \
# 1          Bahrain        2  33  Max Verstappen  Red Bull Racing Honda
# 4          Bahrain        5  11    Sergio Perez  Red Bull Racing Honda
# 20  Emilia Romagna        1  33  Max Verstappen  Red Bull Racing Honda
# 30  Emilia Romagna       11  11    Sergio Perez  Red Bull Racing Honda
# 41        Portugal        2  33  Max Verstappen  Red Bull Racing Honda
#
#     Starting Grid  Laps Time/Retired  Points +1 Pt Fastest Lap
# 1             1.0    56       +0.745    18.0    No    1:33.228
# 4            11.0    56      +52.047    10.0    No    1:33.970
# 20            2.0    63  2:02:34.598    25.0    No    1:17.524
# 30            2.0    63      +67.151     0.0    No    1:18.334
# 41            3.0    66      +29.148    18.0    No    1:20.695

# %%
f1_22_race_results_selects = f1_22_race_results[f1_22_race_results['Driver'].isin(['Max Verstappen', 'Alexander Albon', 'Sergio Perez'])]
f1_22_race_results_selects.head()
# Out:
#            Track Position  No           Driver                  Team  \
# 12       Bahrain       13  23  Alexander Albon     Williams Mercedes
# 17       Bahrain       18  11     Sergio Perez  Red Bull Racing RBPT
# 18       Bahrain       19   1   Max Verstappen  Red Bull Racing RBPT
# 20  Saudi Arabia        1   1   Max Verstappen  Red Bull Racing RBPT
# 23  Saudi Arabia        4  11     Sergio Perez  Red Bull Racing RBPT
#
#     Starting Grid  Laps Time/Retired  Points +1 Pt Fastest Lap
# 12             14    57      +53.932       0    No    1:37.355
# 17              4    56          DNF       0    No    1:36.089
# 18              2    54          DNF       0    No    1:35.440
# 20              4    50  1:24:19.293      25    No    1:31.772
# 23              1    50      +10.800      12    No    1:32.042

# %%
f1_23_race_results_selects = f1_23_race_results[f1_23_race_results['Driver'].isin(['Max Verstappen', 'Alexander Albon', 'Sergio Perez'])]
f1_23_race_results_selects.head()
# Out:
#            Track Position  No           Driver                        Team  \
# 0        Bahrain        1   1   Max Verstappen  Red Bull Racing Honda RBPT
# 1        Bahrain        2  11     Sergio Perez  Red Bull Racing Honda RBPT
# 9        Bahrain       10  23  Alexander Albon           Williams Mercedes
# 20  Saudi Arabia        1  11     Sergio Perez  Red Bull Racing Honda RBPT
# 21  Saudi Arabia        2   1   Max Verstappen  Red Bull Racing Honda RBPT
#
#     Starting Grid  Laps Time/Retired  Points Set Fastest Lap Fastest Lap Time
# 0               1    57  1:33:56.736      25              No         1:36.236
# 1               2    57      +11.987      18              No         1:36.344
# 9              15    57      +89.774       1              No         1:37.144
# 20              1    50  1:21:14.894      25              No         1:32.188
# 21             15    50       +5.335      19             Yes         1:31.906

# %%
f1_24_race_results_selects = f1_24_race_results[f1_24_race_results['Driver'].isin(['Max Verstappen', 'Alexander Albon', 'Sergio Perez'])]
f1_24_race_results_selects.head()
# Out:
#            Track Position  No           Driver                        Team  \
# 0        Bahrain        1   1   Max Verstappen  Red Bull Racing Honda RBPT
# 1        Bahrain        2  11     Sergio Perez  Red Bull Racing Honda RBPT
# 14       Bahrain       15  23  Alexander Albon           Williams Mercedes
# 20  Saudi Arabia        1   1   Max Verstappen  Red Bull Racing Honda RBPT
# 21  Saudi Arabia        2  11     Sergio Perez  Red Bull Racing Honda RBPT
#
#     Starting Grid  Laps Time/Retired  Points Set Fastest Lap Fastest Lap Time
# 0               1    57  1:31:44.742      26             Yes         1:32.608
# 1               5    57      +22.457      18              No         1:34.364
# 14             13    56       +1 lap       0              No         1:35.723
# 20              1    50  1:20:43.273      25              No         1:31.773
# 21              3    50      +13.643      18              No         1:32.273

# %%
#Gasly vs verstappen

Gasly_rb_season_1 = f1_19_race_results_selects[f1_19_race_results_selects['Driver'].isin(['Pierre Gasly', 'Max Verstappen'])]
Gasly_rb_season_1.head()
# Out:
#         Track Position  No          Driver                   Team  \
# 2   Australia        3  33  Max Verstappen  Red Bull Racing Honda
# 10  Australia       11  10    Pierre Gasly  Red Bull Racing Honda
# 23    Bahrain        4  33  Max Verstappen  Red Bull Racing Honda
# 27    Bahrain        8  10    Pierre Gasly  Red Bull Racing Honda
# 43      China        4  33  Max Verstappen  Red Bull Racing Honda
#
#     Starting Grid  Laps Total Time/Gap/Retirement  Points Fastest Lap
# 2               4    58                   +22.520      15          No
# 10             17    57                    +1 lap       0          No
# 23              5    57                    +6.408      12          No
# 27             13    57                   +58.094       4          No
# 43              5    56                   +27.627      12          No

# %%
#Albon vs verstappen

Albon_rb_season_1 = f1_20_race_results_selects[f1_20_race_results_selects['Driver'].isin(['Alexander Albon', 'Max Verstappen'])]
Albon_rb_season_1.head()
# Out:
#       Track Position  No           Driver                   Team  \
# 12  Austria       13  23  Alexander Albon  Red Bull Racing Honda
# 19  Austria       NC  33   Max Verstappen  Red Bull Racing Honda
# 22   Styria        3  33   Max Verstappen  Red Bull Racing Honda
# 23   Styria        4  23  Alexander Albon  Red Bull Racing Honda
# 41  Hungary        2  33   Max Verstappen  Red Bull Racing Honda
#
#     Starting Grid  Laps Total Time/Gap/Retirement  Points Fastest Lap
# 12              4    67                       DNF       0          No
# 19              2    11                       DNF       0          No
# 22              2    71                   +33.698      15          No
# 23              6    71                   +44.400      12          No
# 41              7    70                    +8.702      18          No

# %%
#Perez vs verstappen

Perez_rb_season_1 = f1_21_race_results_selects[f1_21_race_results_selects['Driver'].isin(['Sergio Perez', 'Max Verstappen'])]
Perez_rb_season_1.head()
# Out:
#              Track Position  No          Driver                   Team  \
# 1          Bahrain        2  33  Max Verstappen  Red Bull Racing Honda
# 4          Bahrain        5  11    Sergio Perez  Red Bull Racing Honda
# 20  Emilia Romagna        1  33  Max Verstappen  Red Bull Racing Honda
# 30  Emilia Romagna       11  11    Sergio Perez  Red Bull Racing Honda
# 41        Portugal        2  33  Max Verstappen  Red Bull Racing Honda
#
#     Starting Grid  Laps Time/Retired  Points +1 Pt Fastest Lap
# 1             1.0    56       +0.745    18.0    No    1:33.228
# 4            11.0    56      +52.047    10.0    No    1:33.970
# 20            2.0    63  2:02:34.598    25.0    No    1:17.524
# 30            2.0    63      +67.151     0.0    No    1:18.334
# 41            3.0    66      +29.148    18.0    No    1:20.695

# %%
driver_qualy = f1_qualy[f1_qualy['driverId'].isin([815,830,848,842])]

# %%
driver_qualy
# Out:
#        qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 4547        4549     841       815             15      17        13  1:25.812
# 4574        4577     842       815             15      17        16  1:37.759
# 4594        4597     843       815             15      17        12  1:36.046
# 4621        4624     844       815             15      17        15  1:27.778
# 4641        4644     845       815             15      17        12  1:24.209
# ...          ...     ...       ...            ...     ...       ...       ...
# 10229      10287    1131       848              3      23        16  1:05.736
# 10237      10295    1132       830              9       1         4  1:31.342
# 10242      10300    1132       848              3      23         9  1:31.135
# 10252      10310    1132       815              9      11        19  1:38.348
# 10253      10311    1132       842            214      10        20  1:39.804
#
#              q2        q3
# ...

# %%
f1_races_id_name = f1_races[['raceId','name', 'year']]

# %%
f1_races_id_name
# Out:
#       raceId                    name  year
# 0          1   Australian Grand Prix  2009
# 1          2    Malaysian Grand Prix  2009
# 2          3      Chinese Grand Prix  2009
# 3          4      Bahrain Grand Prix  2009
# 4          5      Spanish Grand Prix  2009
# ...      ...                     ...   ...
# 1120    1140  Mexico City Grand Prix  2024
# 1121    1141    São Paulo Grand Prix  2024
# 1122    1142    Las Vegas Grand Prix  2024
# 1123    1143        Qatar Grand Prix  2024
# 1124    1144    Abu Dhabi Grand Prix  2024
#
# [1125 rows x 3 columns]

# %%
f1_drivers_id_name = f1_drivers[['driverId', 'code','surname']]

# %%
f1_drivers_id_name
# Out:
#      driverId code     surname
# 0           1  HAM    Hamilton
# 1           2  HEI    Heidfeld
# 2           3  ROS     Rosberg
# 3           4  ALO      Alonso
# 4           5  KOV  Kovalainen
# ..        ...  ...         ...
# 854       856  DEV    de Vries
# 855       857  PIA     Piastri
# 856       858  SAR    Sargeant
# 857       859  LAW      Lawson
# 858       860  BEA     Bearman
#
# [859 rows x 3 columns]

# %%
driver_qualy_s = driver_qualy.merge(f1_races_id_name, how='inner', on='raceId')

# %%
driver_qualy_s.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0       4549     841       815             15      17        13  1:25.812
# 1       4577     842       815             15      17        16  1:37.759
# 2       4597     843       815             15      17        12  1:36.046
# 3       4624     844       815             15      17        15  1:27.778
# 4       4644     845       815             15      17        12  1:24.209
#
#          q2  q3                   name  year
# 0  1:26.108  \N  Australian Grand Prix  2011
# 1  1:37.528  \N   Malaysian Grand Prix  2011
# 2  1:36.053  \N     Chinese Grand Prix  2011
# 3  1:27.244  \N     Turkish Grand Prix  2011
# 4  1:23.367  \N     Spanish Grand Prix  2011

# %%
driver_qualy_sel = driver_qualy_s.merge(f1_drivers_id_name, how='inner', on='driverId')

# %%
#quali for each year(to compare quali for each driver)

driver_qualy_sel_19 = driver_qualy_sel[driver_qualy_sel['year'].isin([2019])]
driver_qualy_sel_20 = driver_qualy_sel[driver_qualy_sel['year'].isin([2020])]
driver_qualy_sel_21 = driver_qualy_sel[driver_qualy_sel['year'].isin([2021])]
driver_qualy_sel_22 = driver_qualy_sel[driver_qualy_sel['year'].isin([2022])]
driver_qualy_sel_23 = driver_qualy_sel[driver_qualy_sel['year'].isin([2023])]
driver_qualy_sel_24 = driver_qualy_sel[driver_qualy_sel['year'].isin([2024])]

# %%
driver_qualy_sel_19.head()
# Out:
#      qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 156       7969    1010       815            211      11        10  1:22.908
# 157       7993    1011       815            211      11        14  1:29.893
# 158       8011    1012       815            211      11        12  1:34.026
# 159       8022    1013       815            211      11         5  1:42.249
# 160       8052    1014       815            211      11        15  1:18.286
#
#            q2        q3                   name  year code surname
# 156  1:22.532  1:22.781  Australian Grand Prix  2019  PER   Pérez
# 157  1:29.756        \N     Bahrain Grand Prix  2019  PER   Pérez
# 158  1:33.299        \N     Chinese Grand Prix  2019  PER   Pérez
# 159  1:41.870  1:41.593  Azerbaijan Grand Prix  2019  PER   Pérez
# 160  1:17.886        \N     Spanish Grand Prix  2019  PER   Pérez

# %%
driver_lap_times = f1_lap_times.merge(f1_drivers_id_name, how='inner', on='driverId')

# %%
driver_lap_times_selects = driver_lap_times[driver_lap_times['driverId'].isin([815,830,848,842])]

# %%
driver_lap_times_selects = driver_lap_times_selects.merge(f1_races_id_name, how='inner', on='raceId')

# %%
#lap times by year (to mesure gab to max)

driver_lap_times_selects_19 = driver_lap_times_selects[driver_lap_times_selects['year'].isin([2019])]
driver_lap_times_selects_20 = driver_lap_times_selects[driver_lap_times_selects['year'].isin([2020])]
driver_lap_times_selects_21 = driver_lap_times_selects[driver_lap_times_selects['year'].isin([2021])]
driver_lap_times_selects_22 = driver_lap_times_selects[driver_lap_times_selects['year'].isin([2022])]
driver_lap_times_selects_23 = driver_lap_times_selects[driver_lap_times_selects['year'].isin([2023])]
driver_lap_times_selects_24 = driver_lap_times_selects[driver_lap_times_selects['year'].isin([2024])]

# %%
driver_lap_times_selects_19.head()
# Out:
#        raceId  driverId  lap  position      time  milliseconds code surname  \
# 14075    1010       815    1        12  1:42.296        102296  PER   Pérez
# 14076    1010       815    2        12  1:31.970         91970  PER   Pérez
# 14077    1010       815    3        12  1:31.356         91356  PER   Pérez
# 14078    1010       815    4        12  1:31.743         91743  PER   Pérez
# 14079    1010       815    5        12  1:31.400         91400  PER   Pérez
#
#                         name  year
# 14075  Australian Grand Prix  2019
# 14076  Australian Grand Prix  2019
# 14077  Australian Grand Prix  2019
# 14078  Australian Grand Prix  2019
# 14079  Australian Grand Prix  2019

# %%
#to Compare performance in other teams

f1_23_race_results_williams = f1_23_race_results[f1_23_race_results['Driver'].isin(['Alexander Albon', 'Logan Sargeant'])]
f1_23_race_results_williams.head()
# Out:
#            Track Position  No           Driver               Team  \
# 9        Bahrain       10  23  Alexander Albon  Williams Mercedes
# 11       Bahrain       12   2   Logan Sargeant  Williams Mercedes
# 35  Saudi Arabia       16   2   Logan Sargeant  Williams Mercedes
# 38  Saudi Arabia       NC  23  Alexander Albon  Williams Mercedes
# 55     Australia       16   2   Logan Sargeant  Williams Mercedes
#
#     Starting Grid  Laps Time/Retired  Points Set Fastest Lap Fastest Lap Time
# 9              15    57      +89.774       1              No         1:37.144
# 11             16    56       +1 lap       0              No         1:36.037
# 35             20    50      +86.293       0              No         1:34.469
# 38             17    27          DNF       0              No         1:35.567
# 55             18    56          DNF       0              No         1:21.456

# %%
#to Compare performance in other teams

f1_20_race_results_Torro_Rosso = f1_20_race_results[f1_20_race_results['Driver'].isin(['Yuki Tsunoda','Pierre Gasly'])]
f1_20_race_results_Torro_Rosso.head()
# Out:
#                Track Position  No        Driver              Team  \
# 6            Austria        7  10  Pierre Gasly  AlphaTauri Honda
# 34            Styria       15  10  Pierre Gasly  AlphaTauri Honda
# 59           Hungary       NC  10  Pierre Gasly  AlphaTauri Honda
# 66     Great Britain        7  10  Pierre Gasly  AlphaTauri Honda
# 90  70th Anniversary       11  10  Pierre Gasly  AlphaTauri Honda
#
#     Starting Grid  Laps Total Time/Gap/Retirement  Points Fastest Lap
# 6              12    71                   +16.682       6          No
# 34              7    70                    +1 lap       0          No
# 59             10    15                       DNF       0          No
# 66             11    52                   +31.188       6          No
# 90              7    52                   +70.642       0          No

# %%
#to Compare performance in other teams

f1_20_race_results_racing_point = f1_20_race_results[f1_20_race_results['Driver'].isin(['Sergio Perez','Lance Stroll'])]
f1_20_race_results_racing_point.head()
# Out:
#       Track Position  No        Driver                       Team  \
# 5   Austria        6  11  Sergio Perez  Racing Point BWT Mercedes
# 17  Austria       NC  18  Lance Stroll  Racing Point BWT Mercedes
# 25   Styria        6  11  Sergio Perez  Racing Point BWT Mercedes
# 26   Styria        7  18  Lance Stroll  Racing Point BWT Mercedes
# 43  Hungary        4  18  Lance Stroll  Racing Point BWT Mercedes
#
#     Starting Grid  Laps Total Time/Gap/Retirement  Points Fastest Lap
# 5               6    71                   +15.092       8          No
# 17              9    20                       DNF       0          No
# 25             17    71                   +62.387       8          No
# 26             12    71                   +62.453       6          No
# 43              3    70                   +57.579      12          No

# %%
#SOMETHING WEIRD IS HAPPENING HERE, idk why ist doing this 


f1_constructor_results_1 = f1_constructor_results.merge(f1_races_id_name, how='inner', on='raceId')

# %%
f1_constructor_results_2 = f1_constructor_results_1[f1_constructor_results_1['year'].isin([2019,2020,2021,2022,2023,2024])]
f1_constructor_results_2.head()
# Out:
#        constructorResultsId  raceId  constructorId  points status  \
# 10307                 16881    1120              6    18.0     \N
# 10308                 16880    1120              9    38.0     \N
# 10309                 16883    1120              1    18.0     \N
# 10310                 16882    1120            131    17.0     \N
# 10311                 16884    1120            117     7.0     \N
#
#                        name  year
# 10307  Abu Dhabi Grand Prix  2023
# 10308  Abu Dhabi Grand Prix  2023
# 10309  Abu Dhabi Grand Prix  2023
# 10310  Abu Dhabi Grand Prix  2023
# 10311  Abu Dhabi Grand Prix  2023

# %%
f1_constructor_results_3 = f1_constructor_results_2.merge(f1_constructors, how='inner', on='constructorId')

# %%
f1_constructor_results_3.head()
# Out:
#    constructorResultsId  raceId  constructorId  points status  \
# 0                 16881    1120              6    18.0     \N
# 1                 15852    1010              6    22.0     \N
# 2                 15861    1011              6    26.0     \N
# 3                 15871    1012              6    25.0     \N
# 4                 15881    1013              6    26.0     \N
#
#                   name_x  year constructorRef   name_y nationality  \
# 0   Abu Dhabi Grand Prix  2023        ferrari  Ferrari     Italian
# 1  Australian Grand Prix  2019        ferrari  Ferrari     Italian
# 2     Bahrain Grand Prix  2019        ferrari  Ferrari     Italian
# 3     Chinese Grand Prix  2019        ferrari  Ferrari     Italian
# 4  Azerbaijan Grand Prix  2019        ferrari  Ferrari     Italian
#
#                                              url
# 0  http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 1  http://en.wikipedia.org/wiki/Scuderia_Ferrari
# ...
